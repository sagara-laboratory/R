# %%
DF <- read.table("sample-StaffOvertime.csv",
               sep = ",",  
               header = TRUE,
               stringsAsFactors = FALSE)

# %%
str(DF)
# Out:
# 'data.frame':	325 obs. of  4 variables:
#  $ ID      : int  10012 10015 10019 10020 10022 10023 10025 10026 10027 10028 ...
#  $ section : chr  "Admin" "IT" "IT" "Admin" ...
#  $ tenure  : int  35 34 34 33 33 33 33 32 32 32 ...
#  $ overtime: num  34.2 42.9 38.1 34.7 37.3 47.8 42.4 33.2 31.1 40.8 ...

# %%
head(DF)
# Out:
#   ID    section tenure overtime
# 1 10012 Admin   35     34.2
# 2 10015 IT      34     42.9
# 3 10019 IT      34     38.1
# 4 10020 Admin   33     34.7
# 5 10022 Admin   33     37.3
# 6 10023 IT      33     47.8

# %%
tail(DF)
# Out:
#     ID    section tenure overtime
# 320 29540 Admin   6      14.3
# 321 29541 Admin   6       4.7
# 322 29543 Admin   5      12.1
# 323 29544 Sales   5      40.6
# 324 29555 Sales   4      27.9
# 325 29556 Sales   3      47.3

# %%
summary(DF)
# Out:
#        ID          section              tenure         overtime
#  Min.   :10012   Length:325         Min.   : 1.00   Min.   : 1.20
#  1st Qu.:12050   Class :character   1st Qu.: 8.00   1st Qu.:17.30
#  Median :12135   Mode  :character   Median :13.00   Median :25.90
#  Mean   :13727                      Mean   :14.66   Mean   :25.54
#  3rd Qu.:12319                      3rd Qu.:20.00   3rd Qu.:33.10
#  Max.   :29556                      Max.   :35.00   Max.   :53.70

# %%
hist(DF$overtime, breaks=30, col="orange2")
# Out:
# Plot with title "Histogram of DF$overtime"

# %%
hist(DF$tenure,   breaks=30, col="steelblue")
# Out:
# Plot with title "Histogram of DF$tenure"

# %%
plot(DF$tenure, DF$overtime)
# Out:
# plot without title

# %%
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
ggplot(DF, aes( x=tenure, y=overtime) )+
  geom_point(colour="purple", size=3, alpha=0.7)+
  stat_smooth(method="lm", se=T)
# Out:
# plot without title

# %%
lm( overtime ~ tenure, data=DF)
# Out:
# Call:
# lm(formula = overtime ~ tenure, data = DF)
#
# Coefficients:
# (Intercept)       tenure
#     20.3922       0.3512

# %%
LM1 <- lm( overtime ~ tenure, data=DF)
summary(LM1)
# Out:
# Call:
# lm(formula = overtime ~ tenure, data = DF)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21.9557  -8.2093  -0.2118   7.0907  27.4053
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 20.39225    1.17393  17.371  < 2e-16 ***
# tenure       0.35122    0.06946   5.056 7.17e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 10.52 on 323 degrees of freedom
# Multiple R-squared:  0.07335,	Adjusted R-squared:  0.07048
# F-statistic: 25.57 on 1 and 323 DF,  p-value: 7.174e-07
